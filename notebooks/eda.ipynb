# %% [markdown]
# # EDA
#
# Customer Support Ticket Satisfaction Analysis 데이터셋 탐색용 노트북입니다.

# %%
import pandas as pd
from pathlib import Path

raw_dir = Path('../data/raw')
csv_files = list(raw_dir.glob('*.csv'))
csv_files
